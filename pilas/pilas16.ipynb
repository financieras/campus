# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/campus/blob/main/pilas/pilas16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creación de ficheros ```txt``` con la lista de números aleatorios y la solución por los procedimientos Primero y Segundo

# %%
# FUNCIONES
from random import sample, seed
seed()

def lista_ordenada(lis, orden_inverso=False): # la función da True si ponemos lista_ordenada([4,3,2,1], orden_inverso=True)
    ordenada = False
    aux = lis[:]
    aux.sort(reverse=orden_inverso)
    if aux == lis:
        ordenada = True
    return ordenada

def sa(a,b):
    if len(a) > 1: a[0],a[1] = a[1],a[0]
    return a,b
def sb(a,b):
    if len(b) > 1: b[0],b[1] = b[1],b[0]
    return a,b
def ss(a,b):
    sa(a,b)
    sb(a,b)
    return a,b
def pa(a,b):
    if len(b) > 0:
        a.insert(0, b[0])
        b.pop(0)
    return a,b
def pb(a,b):
    if len(a) > 0:
        b.insert(0, a[0])
        a.pop(0)
    return a,b
def ra(a,b):
    if len(a) > 1: a.append(a.pop(0))
    return a,b
def rb(a,b):
    if len(b) > 1: b.append(b.pop(0))
    return a,b
def rr(a,b):
    ra(a,b)
    rb(a,b)
    return a,b
def rra(a,b):
    if len(a) > 1: a.insert(0, a.pop())
    return a,b
def rrb(a,b):
    if len(b) > 1: b.insert(0, b.pop())
    return a,b
def rrr(a,b):
    rra(a,b)
    rrb(a,b)
    return a,b

def separa(tramo, n, s, a, b):   # se llevan de la pila A a la B los números del tramo que toca
    contador = 0
    ancho = int(n/s)
    fin = tramo * ancho          # fin del tramo
    inicio = (tramo-1)*ancho+1   # inicio del tramo
    pasados = 0   # cuenta cuantos números se han pasado de la pila A a la B
    while pasados < fin-inicio+1: # recorremos los elementos de la plia A hasta que pasemos todos los números de este tramo
        if inicio <= a[0] <= fin:
            pb(a,b)
            contador += 1
            pasados += 1
        else:
            ra(a,b)
            contador += 1
    return a, b, contador

def ordena(tramo, n, s, a, b):   # Pasamos de B a A los del tramo que toca, comenzando por el nº mayor, que para el tramo 1 es 5.
    # ordena los números recientemente separados y llevados a B
    # el objetivo es que esos números queden en B ordenados de forma decreciente: 5,4,3,2,1
    contador = 0
    ancho = int(n/s)
    fin = tramo * ancho          # fin del tramo
    inicio = (tramo-1)*ancho+1   # inicio del tramo
    while not lista_ordenada(b, orden_inverso=True): # se repite hasta que B quede ordenada decrecientemente. Si solo queda un elemento en B es que está ordenada
        while max(b) != b[0]:   # buscamos el máximo y vamos haciendo ra o rra hasta que quede el primero
            if b.index(max(b)) <= int(len(b)/2):
                rb(a,b)
            else:
                rrb(a,b)
            contador += 1
        if not lista_ordenada(b, orden_inverso=True):
            pa(a,b); contador += 1
    while len(a) > n-fin:   # llevamos de A a B los números del tramo que toca
        pb(a,b); contador += 1
    return a, b, contador

def ordena_final(tramo, n, s, a, b):    # ordena los números del úlitmo tramo que están en "A" y el objetivo es que queden crecientes: ...,18,19,20.
    contador = 0
    ancho = int(n/s)
    fin = n           # en el último tramo se ajusta para que el último nº sea igual a n
    inicio = (tramo-1)*ancho+1   # inicio del tramo
    while not lista_ordenada(a): # se repite hasta que A quede ordenada en orden creciente. Si solo queda un elemento en A es que está ordenada
        while min(a) != a[0]:
            if a.index(min(a)) <= int(len(a)/2):
                ra(a,b)
            else:
                rra(a,b)
            contador += 1
        if not lista_ordenada(a):
            pb(a,b); contador += 1
    while len(b) > 0:   # llevamos de B a A todos los números que hay en B
        pa(a,b); contador += 1
    return a, b, contador

# %%
if __name__ == "__main__":
    # Generación de la pila a
    n = 10   # número de elementos de la pila
    a = sample(range(1, n+1), n)
    a_original = a[:]
    b = []
    ######   PROCEDIMIENTO PRIMERO   ######
    contador = 0
    while not lista_ordenada(a):   # se repite hasta que A quede ordenada. Si solo queda un elemento en A es que está ordenada
        while min(a) != a[0]:   # buscamos el mínimo y vamos haciendo ra o rra hasta que quede el primero
            if a.index(min(a)) <= int(len(a)/2):
                ra(a,b)
            else:
                rra(a,b)
            contador += 1
        if not lista_ordenada(a):
            pb(a,b); contador += 1 #print(a,b) # luego hacemos pb
    while len(b) > 0:   # luego se hace pa pa pa pa hasta que no quede nadie en la pila b
        pa(a,b); contador += 1
    primero = contador

    ######   PROCEDIMIENTO SEGUNDO   ######
    a = a_original[:]
    n = len(a)
    b = []
    s = 25   # número de grupos
    contador = 0
    for tramo in range(1, s):   # tramo=1,2,...,s-1. El último tramo se trata de forma diferente
        a, b, contador_separa = separa(tramo,n,s,a,b)   # lleva de A a B los números correspondientes a ese tramo
        contador += contador_separa
        a, b, contador_ordena = ordena(tramo,n,s,a,b)   # ordena los números recientemente separados y llevados a B
        contador += contador_ordena
    # tramo final donde los números de A ya se ordenan en A, ya no se usa la función separa
    # la pila de trabajo es "A" y el objetivo es que sea creciente: ...,18,19,20.
    a, b, contador_ordena_final = ordena_final(tramo,n,s,a,b)
    contador += contador_ordena_final
    #print("Al final:", a, b)
    segundo = contador

    ###   ESCRIBIR ARCHIVO txt   ###
    texto = ''
    for i in a_original:
        if i==1: valor = -32768    # el mínimo int en C
        elif i==2: valor = -99
        elif i==3: valor = 0
        elif i==4: valor = 32767   # el máximo int en C
        else: valor = i
        texto += ''.join(str(valor)) + ' '
    texto = texto[:-1]
    with open('/content/sample_data/'+ str(n) + '_' + str(primero) + '_' + str(segundo) + '.txt', 'w') as writefile:
        writefile.write(texto)

# %%
# !zip -r /content/sample_data/casos.zip /content/sample_data/*.txt
# Out:
#   adding: content/sample_data/1000_122905_22394.txt (deflated 52%)
#   adding: content/sample_data/1000_123822_22330.txt (deflated 52%)
#   adding: content/sample_data/1000_124059_22322.txt (deflated 52%)
#   adding: content/sample_data/1000_125451_22687.txt (deflated 51%)
#   adding: content/sample_data/1000_127063_22481.txt (deflated 52%)
#   adding: content/sample_data/1000_127232_22544.txt (deflated 51%)
#   adding: content/sample_data/1000_127813_22889.txt (deflated 52%)
#   adding: content/sample_data/1000_127917_22355.txt (deflated 51%)
#   adding: content/sample_data/1000_128154_22286.txt (deflated 51%)
#   adding: content/sample_data/1000_129100_22490.txt (deflated 52%)
#   adding: content/sample_data/100_1327_1263.txt (deflated 48%)
#   adding: content/sample_data/100_1353_1389.txt (deflated 48%)
#   adding: content/sample_data/100_1364_1344.txt (deflated 49%)
#   adding: content/sample_data/100_1369_1282.txt (deflated 49%)
#   adding: content/sample_data/100_1393_1359.txt (deflated 49%)
#   adding: content/sample_data/100_1395_1368.txt (deflated 49%)
#   adding: content/sample_data/100_1425_1310.txt (deflated 49%)
#   adding: content/sample_data/100_1447_1428.txt (deflated 49%)
#   adding: content/sample_data/100_1488_1351.txt (deflated 49%)
#   adding: content/sample_data/100_1597_1436.txt (deflated 48%)
#   adding: content/sample_data/10_20_20.txt (stored 0%)
#   adding: content/sample_data/10_21_21.txt (deflated 3%)
#   adding: content/sample_data/10_23_23.txt (stored 0%)
#   adding: content/sample_data/10_27_27.txt (deflated 3%)
#   adding: content/sample_data/10_28_28.txt (deflated 3%)
#   adding: content/sample_data/10_30_30.txt (deflated 3%)
#   adding: content/sample_data/10_31_31.txt (deflated 3%)
#   adding: content/sample_data/10_32_32.txt (deflated 3%)
#   adding: content/sample_data/10_33_33.txt (deflated 3%)
#   adding: content/sample_data/10_35_35.txt (deflated 3%)
#   adding: content/sample_data/5000_3130339_244151.txt (deflated 54%)
#   adding: content/sample_data/5000_3130918_244319.txt (deflated 54%)
#   adding: content/sample_data/5000_3136902_244957.txt (deflated 54%)
#   adding: content/sample_data/500_30967_9255.txt (deflated 53%)
#   adding: content/sample_data/500_31553_9228.txt (deflated 54%)
#   adding: content/sample_data/500_31730_9471.txt (deflated 53%)
#   adding: content/sample_data/500_32213_9580.txt (deflated 53%)
#   adding: content/sample_data/500_32560_9413.txt (deflated 53%)
#   adding: content/sample_data/500_33271_9490.txt (deflated 53%)
#   adding: content/sample_data/500_33304_9490.txt (deflated 53%)
#   adding: content/sample_data/500_33431_9546.txt (deflated 54%)
#   adding: content/sample_data/500_33584_9354.txt (deflated 53%)
#   adding: content/sample_data/500_34570_9317.txt (deflated 53%)
#   adding: content/sample_data/50_355_484.txt (deflated 42%)
#   adding: content/sample_data/50_383_523.txt (deflated 43%)
#   adding: content/sample_data/50_388_532.txt (deflated 42%)
#   adding: content/sample_data/50_391_492.txt (deflated 42%)
#   adding: content/sample_data/50_421_522.txt (deflated 43%)
#   adding: content/sample_data/50_439_515.txt (deflated 42%)
#   adding: content/sample_data/50_440_580.txt (deflated 42%)
#   adding: content/sample_data/50_442_577.txt (deflated 43%)
#   adding: content/sample_data/50_443_563.txt (deflated 43%)
#   adding: content/sample_data/50_449_567.txt (deflated 42%)
